# %%
import PIL.Image

# %%
im = PIL.Image.open('/shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/datasets/images/flower.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
import numpy
mat = numpy.asarray(im)
mat.shape
# Out:
# (427, 640, 3)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5292883e-50a7-4f1d-9f12-778c1d6da182' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
