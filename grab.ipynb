# %%
from PIL import ImageGrab
im = ImageGrab.grab(bbox=(0,0,1366,768))
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768 at 0x16D66173FD0>

# %%
from PIL import ImageGrab
im = ImageGrab.grab(bbox=(0,0,1366,768))
im.save('screen.png')

# %%
from PIL import Image as show1
display(show1.open('screen.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1366x768 at 0x1D77FCD6520>

# %%
from IPython.display import Image as show2
display(show2('screen.png'))

# %%
from pynput.mouse import Controller
mouse = Controller()
print(mouse.position)
# Out:
# (1188, 461)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5292883e-50a7-4f1d-9f12-778c1d6da182' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
