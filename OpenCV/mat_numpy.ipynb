# %%
import deepnote.deepcv as cv
import numpy as np
zero255 = np.zeros((600, 600, 3), np.int8)
cv.showColor(zero255 + 128)

# %%
import deepnote.deepcv as cv
import numpy as np
empty255 = np.empty((600, 600, 3), np.int8)
cv.showColor(empty255 + 128)

# %%
import deepnote.deepcv as cv
import numpy as np
one255 = np.ones((600, 600, 3), np.int8)
cv.showColor(one255 * 128)

# %%
import cv2 as cv
print( cv.__version__ )
# Out:
# 4.5.5

# %% [markdown]
# ### 转为numpy数组

# %% [markdown]
# numpy.array(object, dtype = None, copy = True, order = None, subok = False, ndmin = 0)

# %% [markdown]
# numpy.asarray(a, dtype = None, order = None)

# %% [markdown]
# numpy.frombuffer(buffer, dtype = float, count = -1, offset = 0)

# %% [markdown]
# numpy.fromiter(iterable, dtype, count=-1)

# %% [markdown]
# ### 转换维度（图片形状）

# %% [markdown]
# np.reshape()

# %% [markdown]
# np.size      np.shape

# %% [markdown]
# ### 数据类型

# %% [markdown]
# np.dtype()

# %% [markdown]
# ### 切片、索引（ROI）

# %% [markdown]
# s = slice(2,7,2)   # 从索引 2 开始到索引 7 停止，间隔为2

# %% [markdown]
# b = a[2:7:2]   # 从索引 2 开始到索引 7 停止，间隔为 2

# %% [markdown]
# ### 拷贝

# %% [markdown]
# ndarray.flatten(order='C')

# %% [markdown]
# a.view()

# %% [markdown]
# ndarray.copy()&nbsp;

# %% [markdown]
# ### 旋转、翻转

# %% [markdown]
# numpy.transpose(arr, axes)

# %% [markdown]
# ndarray.T

# %% [markdown]
# ### 扩展、追加

# %% [markdown]
# numpy.expand_dims(arr, axis)

# %% [markdown]
# numpy.append(arr, values, axis=None)

# %% [markdown]
# numpy.insert(arr, obj, values, axis)

# %% [markdown]
# Numpy.delete(arr, obj, axis)

# %% [markdown]
# ### 合并、拼接

# %% [markdown]
# numpy.concatenate((a1, a2, ...), axis)

# %% [markdown]
# ### 分割

# %% [markdown]
# numpy.split(ary, indices_or_sections, axis)

# %% [markdown]
# ### 去重

# %% [markdown]
# numpy.unique(arr, return_index, return_inverse, return_counts)

# %% [markdown]
# ### 数学

# %% [markdown]
# sin     cos     tan     degrees      amin     amax     ptp        median          mean          average           std          var

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/work/f103/IMG_20210929_183143.jpg')
plt.figure(figsize=(10,10))
imgplot = plt.imshow(img)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=26e5d5b4-a604-4f7b-aef4-7756f8127ef0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
