# %% [markdown]
# # mnist-MobileNetV2

# %%
import tensorflow as tf
(tri, trl), (tsi, tsl) = tf.keras.datasets.mnist.load_data()
tri, tsi = tri / 255.0, tsi / 255.0
tri = tri.reshape(tri.shape[0], 28, 28, 1)
tsi = tsi.reshape(tsi.shape[0], 28, 28, 1)
tri = tf.image.resize(tri, [32,32])
tsi = tf.image.resize(tsi, [32,32])
mobile_net = tf.keras.applications.MobileNetV2(input_shape=(32, 32, 1), weights=None, classes=10)
mobile_net.trainable=True
mobile_net.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mobile_net.fit(tri, trl, epochs=10)
mobile_net.evaluate(tsi, tsl, verbose=2)

# %% [markdown]
# # ImageNet-MobileNetV2

# %%
import tensorflow as tf
mobile_net = tf.keras.applications.MobileNetV2(input_shape=(192, 192, 3), include_top=True)
mobile_net.trainable=False
mobile_net.summary()
# Out:
# ...
# 14540800/14536120 [==============================] - 0s 0us/step
# Model: "mobilenetv2_1.00_192"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 96, 96, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 96, 96, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 96, 96, 32)   0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
img = tf.keras.preprocessing.image.load_img('/work/plane.jpg', target_size=(192, 192))
img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = mobile_net.predict(img_array)
score = tf.nn.softmax(predictions[0])
import numpy as np
print("这张图片属于类别编号： {} 准确率： {:.2f} ".format(np.argmax(score), 100 * np.max(score)))
# Out:
# 这张图片属于类别编号： 812 准确率： 0.12

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=26e5d5b4-a604-4f7b-aef4-7756f8127ef0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
